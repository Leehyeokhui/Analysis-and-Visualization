# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
columns = ['sepal_width','sepal_length','species']
df[columns].head()
# Out:
#    sepal_width  sepal_length species
# 0          3.5           5.1  setosa
# 1          3.0           4.9  setosa
# 2          3.2           4.7  setosa
# 3          3.1           4.6  setosa
# 4          3.6           5.0  setosa

# %%
df.sepal_width #한글이나 특수문자 있으면 .으로 불러올 수 없을 수 있다.
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df.filter(regex='_') 
# columns 명에 '_' 포함되어 있는 column 가져오기
# 대소문자 구분하기
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.filter(regex='^sepal')
# sepal로 시작
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df.filter(regex='length$')
# length로 끝
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# * loc와 iloc의 차이는 index를 포함하는가의 차이

# %%
df.loc[:,'sepal_width':'petal_width']
# Out:
#      sepal_width  petal_length  petal_width
# 0            3.5           1.4          0.2
# 1            3.0           1.4          0.2
# 2            3.2           1.3          0.2
# 3            3.1           1.5          0.2
# 4            3.6           1.4          0.2
# ..           ...           ...          ...
# 145          3.0           5.2          2.3
# 146          2.5           5.0          1.9
# 147          3.0           5.2          2.0
# 148          3.4           5.4          2.3
# 149          3.0           5.1          1.8
#
# [150 rows x 3 columns]

# %%
df.iloc[:,[1,3]]
# Out:
#      sepal_width  petal_width
# 0            3.5          0.2
# 1            3.0          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 4            3.6          0.2
# ..           ...          ...
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8
#
# [150 rows x 2 columns]

# %%
df.loc[df['sepal_length'] > 7, ['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 102           7.1          3.0
# 105           7.6          3.0
# 107           7.3          2.9
# 109           7.2          3.6
# 117           7.7          3.8
# 118           7.7          2.6
# 122           7.7          2.8
# 125           7.2          3.2
# 129           7.2          3.0
# 130           7.4          2.8
# 131           7.9          3.8
# 135           7.7          3.0
